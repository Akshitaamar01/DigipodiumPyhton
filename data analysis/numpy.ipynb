# %% [markdown]
# # numpy
# - create array
# - maths
# - operations

# %%
x = [[1,2,3],
    [3,2,1]]
print(x)
# Out:
# [[1, 2, 3], [3, 2, 1]]

# %% [markdown]
# # slicing

# %%
import numpy as np
x = np.random.randint(0,20,15)
print(x)
# Out:
# [ 6 15  4  6  5  7  9 17 13 15 11  6 19 10 11]

# %%
print (x[:5])
print(x[5:])
print(x[-5:])
# Out:
# [ 6 15  4  6  5]
# [ 7  9 17 13 15 11  6 19 10 11]
# [11  6 19 10 11]

# %%
z = x = np.random.randint(0,20,(6,6))
print (z)
# Out:
# [[ 5 16 13  6 12  0]
#  [13  5  3  7  4 13]
#  [ 0 17  1 11  2  8]
#  [ 2  9  2  7 16  7]
#  [18 12  8 15  3  8]
#  [18 15 15  3  1  3]]

# %%
print ('row[0] =>', z[0])
print ('row[2,3,4] => \n', z[2:5])
print('first element', z[0,0])
print('last element', z[-1,-1])
print('first row, last element =>' , z[0,-1])
# Out:
# row[0] => [ 5 16 13  6 12  0]
# row[2,3,4] =>
#  [[ 0 17  1 11  2  8]
#  [ 2  9  2  7 16  7]
#  [18 12  8 15  3  8]]
# first element 5
# last element 3
# first row, last element => 0

# %%
import matplotlib.pyplot as plt

# %%
t = np.arange(0, 3*np.pi, .1)
x = np.sin(t)
y = np.cos(t)
plt.plot(t,x, 'go:')

# %%
plt.plot(t, y, 'go:', label='cos(t)')
plt.plot(t,x, 'rx', label = 'sin(t)')
plt.legend()
plt.grid()

# %%
d = np.random.randn(1000)
plt.hist(d, bins=50)
plt.show()

# %%
d=np.random.randn(1000)
plt.hist(d, bins=list(range(-3,4)))
plt.show()

# %%
plt.boxplot(x)
plt.show()

# %%
 def find_max(nums):
    max_num = float("-inf") # smaller than all other numbers
    for num in nums:
        if num > max_num:
            # (Fill in the missing line here)
    return max_num
# Out:
#   Cell In[2], line 6
#     return max_num
#     ^
# IndentationError: expected an indented block after 'if' statement on line 4
